# %% [markdown]
# ---
# # Operações Vetoriais
# ### Manipulação de Matrizes com NumPy
# ---

# %% [markdown]
# ### 01 - O que é e quando usar o NumPy
#
# **NumPy** é uma biblioteca do Python usada para computação numérica.
#
# Ela serve principalmente para:
#
# * criar e manipular arrays e matrizes de forma eficiente
# * fazer operações matemáticas e vetoriais rapidamente
# * trabalhar com álgebra linear, estatística e funções matemáticas
#
# A principal vantagem sobre listas normais do Python é performance e praticidade em cálculos com muitos dados.
#
# Em resumo: **NumPy** é a base do trabalho com dados numéricos em Python, e muitas bibliotecas como pandas, scikit-learn e partes do matplotlib dependem dele.

# %%
import numpy as np
import math
import time

# %%
# lista (vetor) com numpy de 10 milhoes de itens
precos_np = np.random.rand(10_000_000)
type(precos_np)
# Out:
# numpy.ndarray

# %%
# lista (estrutura de dados padrao em python puro)
precos_list = list(precos_np)
type(precos_list)
# Out:
# list

# %%
# operacao com numpy
tempo_inicial = time.time()
desconto = precos_np * 0.0
resultado_final = desconto + 5
raiz = np.sqrt(precos_np)
print("Numpy:", time.time() - tempo_inicial, "segundos")
# Out:
# Numpy: 0.42557454109191895 segundos

# %%
# mesma operacao com python puro
tempo_inicial = time.time()
desconto = [preco * 0.9 for preco in precos_list]
resultado_final = [preco + 5 for preco in desconto]
print("Python puro:", time.time() - tempo_inicial, "segundos")
# Out:
# Python puro: 1.721064805984497 segundos

# %% [markdown]
# **Nota:**
#
# Para 10 milhões de valores, o NumPy normalmente é muito mais rápido. Mas para poucos valores, o uso de loops com Python puro pode sair na frente porque o overhead do NumPy pesa mais que o ganho para poucos registros.
#
# **Resumindo:**
#
# - Poucos elementos → Loops Python podem ser mais rápidos (overhead do NumPy é maior).
#
# - Muitos elementos → NumPy é muito mais rápido e escalável.

# %% [markdown]
# ---
# ### 02 - O objeto ndarray
#
# Um array NumPy é uma estrutura de dados multidimensional usada em computação científica e análise de dados. O NumPy fornece um objeto de matriz N-dimensional (ou ndarray), que é uma grade homogênea de elementos, geralmente números, que podem ser indexados por um conjunto de inteiros.
#
# Os arrays NumPy são mais eficientes do que as listas Python para armazenar e manipular grandes quantidades de dados, pois são implementados em Linguagem C e fornecem várias otimizações de desempenho. Além disso, o NumPy permite a fácil leitura e escrita de arquivos de dados, integração com outras bibliotecas Python e suporte a operações em paralelo usando várias CPUs ou GPUs.
#
# <img src="imagem1.png" alt="DSA" width="700" height="400">
